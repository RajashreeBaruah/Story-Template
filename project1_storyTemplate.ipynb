# %%
my_adj = input("Please type an adjective: ")
my_verb1 = input("Please type a verb: ")
my_verb2 = input("Please type another verb: ")

story_time = "What a {adj} day it is! Ram and Shyam are very good friends. They {verb1} together. Ram and Shyam {verb2} a lot.".format(adj = my_adj, verb1 = my_verb1, verb2 = my_verb2)
print("\n\nStory time kids!!\n")
print(story_time)
# Out:
# Please type an adjective: beautiful
# Please type a verb: walk
# Please type another verb: play
#
#
# Story time kids!!
#
# What a beautiful day it is! Ram and Shyam are very good friends. They walk together. Ram and Shyam play a lot.
